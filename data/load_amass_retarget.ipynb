# %%
import numpy as np

data=np.load('amass/amass_retargeted.npy', allow_pickle=True)
data.shape,
# Out:
# ((2000, 125, 1, 17, 3),)

# %%
data[...,0]
# Out:
# array([[[[ 0.        , -0.02976736,  0.07790536, ...,  0.37709907,
#            0.30015001,  0.50380105]],
#
#         [[ 0.        , -0.02980457,  0.07831688, ...,  0.37770265,
#            0.30403122,  0.50589937]],
#
#         [[ 0.        , -0.02954862,  0.07895266, ...,  0.37852433,
#            0.30628967,  0.50576442]],
#
#         ...,
#
#         [[ 0.        , -0.03079535,  0.10135408, ...,  0.38081104,
#            0.29040128,  0.47862127]],
#
#         [[ 0.        , -0.02995831,  0.10173804, ...,  0.37864861,
#            0.28401154,  0.47231153]],
#
#         [[ 0.        , -0.02916565,  0.10176245, ...,  0.37656772,
#            0.27943939,  0.46767274]]],
#
#
#        [[[ 0.        , -0.05307508, -0.1167997 , ..., -0.13954856,
#           -0.30951631, -0.31090707]],
#
#         [[ 0.        , -0.05305633, -0.11677328, ..., -0.14187878,
#           -0.3013435 , -0.29922056]],
#
#         [[ 0.        , -0.05312903, -0.11693491, ..., -0.14381309,
# ...
